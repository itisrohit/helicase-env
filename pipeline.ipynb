# %% [markdown]
# # Twinkle + dsDNA Simulation Pipeline
# This notebook guides you through the setup of the coarse-grained simulation environment.

# %% [markdown]
# ## 1. Clean the Protein
# Downloads 7T8C and extracts the hexamer.

# %%
# !uv run python src/01_clean.py

# %% [markdown]
# ## 2. Generate DNA
# Extracts a 30bp segment from a standard template.

# %%
# !uv run python src/02_build_dna.py

# %% [markdown]
# ## 3. Coarse-Grain
# Converts atomistic structures to MARTINI 3 resolution.

# %%
# !uv run python src/03_coarse_grain.py

# %% [markdown]
# ## 4. Assemble & Solvate
# Merge the system and add water/ions.

# %%
# !uv run python src/04_merge.py
# !uv run python src/05_solvate.py

# %% [markdown]
# ## 5. Visualize
# Verify the system setup.

# %%
import nglview as nv

view = nv.show_file("cg/solvated_system.pdb")
view
