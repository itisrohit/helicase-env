# %% [markdown]
# # Twinkle + dsDNA Delivery Pipeline
#
# This notebook runs the delivered local-environment workflow end to end.

# %% [markdown]
# ## 1. Clean Twinkle
# Download 7T8C and extract the hexamer.

# %%
# !uv run python src/01_clean.py

# %% [markdown]
# ## 2. Validate DNA input
# Check the provided 30 bp DNA structure used by the delivery path.

# %%
# !uv run python src/02_build_dna.py

# %% [markdown]
# ## 3. Coarse-grain
# Build the consistent Martini 2 delivery branch.

# %%
# !uv run python src/03_coarse_grain.py

# %% [markdown]
# ## 4. Merge
# Place the DNA through the Twinkle ring center.

# %%
# !uv run python src/04_merge.py

# %% [markdown]
# ## 5. Build local environment
# Create the local water + ion environment.

# %%
# !uv run python src/05_solvate.py

# %% [markdown]
# ## 6. Build HPC handoff bundle
# Package the final handoff directory for cluster-side GROMACS preparation.

# %%
# !uv run python src/06_simulate.py

# %% [markdown]
# ## 7. Visualize
# Open the dedicated visualization notebook next.

# %%
from pathlib import Path

Path("notebooks/visualize.ipynb")
